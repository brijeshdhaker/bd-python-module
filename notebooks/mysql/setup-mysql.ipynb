# %%
# %pip install ipython-sql pymysql jupysql duckdb-engine grpcio toml cryptography

# %%
# %conda install mysqlclient -c conda-forge --quiet

# %%
# %%bash
#
# docker compose -f /home/brijeshdhaker/IdeaProjects/bd-notebooks-module/docker-compose.yml up -d mysqlserver

# %% [markdown]
# ##### Setup User & Databases
#
#
# ```

# %%
# %load_ext sql

# %%
# %sql mysql+pymysql://mysqladmin:paSSW0rd@mysqlserver.sandbox.net:3306/SANDBOXDB

# %%
# No Need to Run This Again
# %config SqlMagic.style = '_DEPRECATED_DEFAULT'

# %%
# %%sql
# show databases;

# %%
# %%sql
#
# USE SANDBOXDB;

# %%
# %%sql
# show tables;

# %%
# %sql select * from NEETASTUDIO.CUSTOMER_ENQUIRIES LIMIT 5

# %%
# %%sql
#
# select * from NEETASTUDIO.CUSTOMER_ENQUIRIES LIMIT 5

# %%
# %%sql
#
# SELECT SUBSTRING_INDEX('www.mysql.com', '.', 2);

# %%
# %%sql
#
# SELECT SUBSTRING_INDEX('www.mysql.com', '.', -2);

# %%
# %%sql
#
# SELECT
#     SUBSTRING_INDEX('www.mysql.com', '.', 1) AS W1,
#     SUBSTRING_INDEX(SUBSTRING_INDEX('www.mysql.com', '.', 2), '.', -1) AS W2,
#     SUBSTRING_INDEX(SUBSTRING_INDEX('www.mysql.com', '.', 3), '.', -1) AS W3

# %%
# %%bash
#
# sqlite3mysql -f /home/brijeshdhaker/IdeaProjects/bd-notebooks-module/notebooks/mysql/Chinook_Sqlite.sqlite -u mysqladmin -p -d SANDBOXDB -h mysqlserver.sandbox.net

# %%
# %%bash
#
# mysqldump -u root -p SANDBOXDB > /apps/SANDBOXDB_full_db_backup.sql
#
# mysqldump -u mysqladmin -p --no-create-info SANDBOXDB > /apps/data_only.sql

# %%
# %%bash
#
# mysql -u root -p SANDBOXDB < /apps/SANDBOXDB_full_db_backup.sql
