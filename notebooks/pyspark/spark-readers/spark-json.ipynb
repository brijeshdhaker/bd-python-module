# %%
from pyspark.sql import SparkSession

spark = (
    SparkSession
    .builder
    .appName("spark-sql-json")
    .master("local[*]").config("spark.ui.port", "4042")
    .getOrCreate()
)
print(spark.sparkContext.uiWebUrl)
spark
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/03/27 08:16:44 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# http://vmware-kubuntu.sandbox.net:4042
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://vmware-kubuntu.sandbox.net:4042">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.3</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>spark-sql-json</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
from pyspark.sql.types import StructType, StructField, StringType, DoubleType, StructType, TimestampType

schema = StructType([
    StructField("user_id", StringType(), True),
    StructField("name", StringType(), True),
    StructField("event", StringType(), True),
    StructField("amount", DoubleType(), True),
    StructField("currency", StringType(), True),
    StructField("location", StructType([
        StructField("lat", DoubleType(), True),
        StructField("long", DoubleType(), True)
    ])),
    StructField("timestamp", StringType(), True) 
])

# %% [markdown]
# #### Method: from_json()

# %%
from pyspark.sql.functions import from_json

# Sample data received from Kafka
data = [
    ('{"user_id": "user_123", "name": "Alice Johnson", "event": "transaction", "amount": 250.75, "currency": "USD", "location": {"lat": 40.7128, "long": -74.0060}, "timestamp": "2025-03-19T14:30:00"}',)
]

df = spark.createDataFrame(data, ["json_event"])

# Parse JSON
df_parsed = df.withColumn("parsed_data", from_json("json_event", schema))
df_parsed.show(truncate=False)
# Out:
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------+
# |json_event                                                                                                                                                                                       |parsed_data                                                                                 |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------+
# |{"user_id": "user_123", "name": "Alice Johnson", "event": "transaction", "amount": 250.75, "currency": "USD", "location": {"lat": 40.7128, "long": -74.0060}, "timestamp": "2025-03-19T14:30:00"}|{user_123, Alice Johnson, transaction, 250.75, USD, {40.7128, -74.006}, 2025-03-19T14:30:00}|
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------+

# %%
df_final = df_parsed.select(
    "parsed_data.user_id",
    "parsed_data.name",
    "parsed_data.event",
    "parsed_data.amount",
    "parsed_data.currency",
    "parsed_data.location.lat",
    "parsed_data.location.long",
    "parsed_data.timestamp"
)
df_final.show(truncate=False)
# Out:
# +--------+-------------+-----------+------+--------+-------+-------+-------------------+
# |user_id |name         |event      |amount|currency|lat    |long   |timestamp          |
# +--------+-------------+-----------+------+--------+-------+-------+-------------------+
# |user_123|Alice Johnson|transaction|250.75|USD     |40.7128|-74.006|2025-03-19T14:30:00|
# +--------+-------------+-----------+------+--------+-------+-------+-------------------+

# %% [markdown]
# #### Method: get_json_object()

# %%
from pyspark.sql.functions import get_json_object

df_extracted = df.select(
    get_json_object("json_event", "$.user_id").alias("user_id"),
    get_json_object("json_event", "$.amount").alias("transaction_amount"),
    get_json_object("json_event", "$.location.lat").alias("latitude"),
    get_json_object("json_event", "$.location.long").alias("longitude"),
    get_json_object("json_event", "$.timestamp").alias("event_time")
)

df_extracted.show(truncate=False)
# Out:
# +--------+------------------+--------+---------+-------------------+
# |user_id |transaction_amount|latitude|longitude|event_time         |
# +--------+------------------+--------+---------+-------------------+
# |user_123|250.75            |40.7128 |-74.006  |2025-03-19T14:30:00|
# +--------+------------------+--------+---------+-------------------+

# %% [markdown]
# #### Method: to_json()

# %%
from pyspark.sql.functions import to_json, struct

df_json = df_final.withColumn("json_output", to_json(struct(
    "user_id", "name", "event", "amount", "currency", "lat", "long", "timestamp"
)))

df_json.show(truncate=False)
# Out:
# +--------+-------------+-----------+------+--------+-------+-------+-------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |user_id |name         |event      |amount|currency|lat    |long   |timestamp          |json_output                                                                                                                                                        |
# +--------+-------------+-----------+------+--------+-------+-------+-------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |user_123|Alice Johnson|transaction|250.75|USD     |40.7128|-74.006|2025-03-19T14:30:00|{"user_id":"user_123","name":"Alice Johnson","event":"transaction","amount":250.75,"currency":"USD","lat":40.7128,"long":-74.006,"timestamp":"2025-03-19T14:30:00"}|
# +--------+-------------+-----------+------+--------+-------+-------+-------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------+

# %% [markdown]
# #### Method: json_tuple()

# %%
from pyspark.sql.functions import json_tuple, col

df_extracted = df.select(json_tuple(col('json_event'), 'user_id', 'event', 'amount', 'timestamp')
                         .alias('user_id', 'event_type', 'amount', 'event_time'))
df_extracted.show(truncate=False)
# Out:
# +--------+-----------+------+-------------------+
# |user_id |event_type |amount|event_time         |
# +--------+-----------+------+-------------------+
# |user_123|transaction|250.75|2025-03-19T14:30:00|
# +--------+-----------+------+-------------------+

# %% [markdown]
# #### Method: schema_of_json()

# %%
from pyspark.sql.functions import from_json, schema_of_json

sample_json = df.select("json_event").limit(1).collect()[0][0]
schema_inferred = df.select(schema_of_json(lit(sample_json))).collect()[0][0]
print(schema_inferred)

df_parsed = df.withColumn("parsed_data", from_json("json_event", schema_inferred))
df_parsed.select("parsed_data.*").show(truncate=False)
# Out:
# STRUCT<amount: DOUBLE, currency: STRING, event: STRING, location: STRUCT<lat: DOUBLE, long: DOUBLE>, name: STRING, timestamp: STRING, user_id: STRING>
# +------+--------+-----------+------------------+-------------+-------------------+--------+
# |amount|currency|event      |location          |name         |timestamp          |user_id |
# +------+--------+-----------+------------------+-------------+-------------------+--------+
# |250.75|USD     |transaction|{40.7128, -74.006}|Alice Johnson|2025-03-19T14:30:00|user_123|
# +------+--------+-----------+------------------+-------------+-------------------+--------+

# %% [markdown]
# #### Error Handling (mode): Control how PySpark handles corrupt or malformed records.
#
# `PERMISSIVE` (default): Sets malformed records to null and places the original corrupt string in a _corrupt_record column.
#
# `DROPMALFORMED`: Drops rows containing malformed JSON data.
#
# `FAILFAST`: Throws an error immediately upon encountering a corrupt record.

# %%
jsondf = spark.read \
    .option("multiLine", True) \
    .option("mode", "DROPMALFORMED") \
    .json("file:///apps/sandbox/datasets/taxi-data/nyc_film_permits.json")

jsondf.show(truncate=False)
# Out:
# +---------+-----------------+----------------+------------------------+-----------------------+-----------------------+---------------------------------------+-------+-----------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------+-----------------------+---------------+----------------------------------------+
# |borough  |category         |communityboard_s|country                 |enddatetime            |enteredon              |eventagency                            |eventid|eventtype                    |parkingheld                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |policeprecinct_s|startdatetime          |subcategoryname|zipcode_s                               |
# +---------+-----------------+----------------+------------------------+-----------------------+-----------------------+---------------------------------------+-------+-----------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------+-----------------------+---------------+----------------------------------------+
# |Queens   |Television       |5               |United States of America|2024-06-04T20:00:00.000|2024-06-03T11:36:12.000|Mayor's Office of Media & Entertainment|789792 |Shooting Permit              |COVERT ST between WYCKOFF AVENUE and IRVING AVENUE                                                                                                                                                                                                                                                                                                                                                                                                                                                             |104             |2024-06-04T06:00:00.000|Episodic series|11237, 11385                            |
# |Manhattan|Still Photography|11, 64, 8       |United States of America|2024-06-04T21:00:00.000|2024-05-31T14:51:57.000|Mayor's Office of Media & Entertainment|788711 |Shooting Permit              |5 AVENUE between EAST  103 STREET and EAST   98 STREET,  5 AVENUE between EAST  103 STREET and EAST  105 STREET,  EAST  103 STREET between 5 AVENUE and MADISON AVENUE,  EAST  104 STREET between 5 AVENUE and MADISON AVENUE                                                                                                                                                                                                                                                                                  |19, 22, 23      |2024-06-04T06:00:00.000|Not Applicable |10024, 10025, 10029, 10128              |
# |Manhattan|Film             |8               |United States of America|2024-06-04T23:30:00.000|2024-05-31T14:20:45.000|Mayor's Office of Media & Entertainment|788696 |Shooting Permit              |EAST   83 STREET between 3 AVENUE and LEXINGTON AVENUE,  3 AVENUE between EAST   83 STREET and EAST   84 STREET,  EAST   82 STREET between 2 AVENUE and 3 AVENUE,  3 AVENUE between EAST   83 STREET and EAST   84 STREET                                                                                                                                                                                                                                                                                      |19              |2024-06-04T09:00:00.000|Feature        |10028                                   |
# |Manhattan|Still Photography|11, 64, 8       |United States of America|2024-06-04T19:00:00.000|2024-05-31T14:20:07.000|Mayor's Office of Media & Entertainment|788695 |Shooting Permit              |EAST   90 STREET between 5 AVENUE and MADISON AVENUE,  MADISON AVENUE between EAST   90 STREET and EAST   91 STREET,  EAST   90 STREET between 5 AVENUE and MADISON AVENUE,  MADISON AVENUE between EAST   96 STREET and EAST   97 STREET                                                                                                                                                                                                                                                                      |19, 22, 23      |2024-06-04T07:00:00.000|Not Applicable |10023, 10024, 10025, 10029, 10128       |
# |Manhattan|Film             |4, 5            |United States of America|2024-06-04T18:00:00.000|2024-05-31T13:54:53.000|Mayor's Office of Media & Entertainment|788669 |Shooting Permit              |WEST   50 STREET between BROADWAY and 8 AVENUE,  WEST   51 STREET between BROADWAY and 8 AVENUE,  BROADWAY between WEST   51 STREET and WEST   52 STREET,  WEST   51 STREET between 7 AVENUE and BROADWAY,  7 AVENUE between WEST   50 STREET and WEST   51 STREET,  8 AVENUE between WEST   50 STREET and WEST   51 STREET,  WEST   51 STREET between 6 AVENUE and 7 AVENUE,  WEST   50 STREET between 6 AVENUE and 7 AVENUE,  7 AVENUE between WEST   49 STREET and WEST   50 STREET                         |18              |2024-06-04T08:00:00.000|Feature        |10019, 10020                            |
# |Brooklyn |Still Photography|6               |United States of America|2024-06-04T21:00:00.000|2024-05-31T11:20:42.000|Mayor's Office of Media & Entertainment|788598 |Shooting Permit              |HENRY STREET between PRESIDENT STREET and UNION STREET,  PRESIDENT STREET between HENRY STREET and CLINTON STREET                                                                                                                                                                                                                                                                                                                                                                                              |76              |2024-06-04T07:00:00.000|Not Applicable |11231                                   |
# |Manhattan|Commercial       |2               |United States of America|2024-06-04T23:00:00.000|2024-05-31T10:31:26.000|Mayor's Office of Media & Entertainment|788584 |Shooting Permit              |GREENWICH STREET between WEST HOUSTON STREET and CLARKSON STREET                                                                                                                                                                                                                                                                                                                                                                                                                                               |6               |2024-06-04T06:00:00.000|Commercial     |10014                                   |
# |Manhattan|WEB              |8               |United States of America|2024-06-03T21:00:00.000|2024-05-31T10:22:25.000|Mayor's Office of Media & Entertainment|788581 |Shooting Permit              |EAST   95 STREET between 1 AVENUE and 2 AVENUE                                                                                                                                                                                                                                                                                                                                                                                                                                                                 |19              |2024-06-03T06:00:00.000|Not Applicable |10128                                   |
# |Manhattan|Commercial       |2               |United States of America|2024-06-03T23:00:00.000|2024-05-30T20:56:05.000|Mayor's Office of Media & Entertainment|788522 |Shooting Permit              |GREENWICH STREET between CLARKSON STREET and WEST HOUSTON STREET                                                                                                                                                                                                                                                                                                                                                                                                                                               |6               |2024-06-03T06:00:00.000|Commercial     |10014                                   |
# |Manhattan|Television       |5               |United States of America|2024-06-04T23:59:00.000|2024-05-30T17:27:56.000|Mayor's Office of Media & Entertainment|788499 |Shooting Permit              |WEST   41 STREET between 7 AVENUE and 8 AVENUE                                                                                                                                                                                                                                                                                                                                                                                                                                                                 |14              |2024-06-04T06:00:00.000|Morning Show   |10036                                   |
# |Manhattan|Still Photography|9               |United States of America|2024-06-04T21:00:00.000|2024-05-30T15:31:09.000|Mayor's Office of Media & Entertainment|788453 |Shooting Permit              |12 AVENUE between WEST  133 STREET and WEST  134 STREET,  12 AVENUE between WEST  133 STREET and WEST  132 STREET                                                                                                                                                                                                                                                                                                                                                                                              |26, 30          |2024-06-04T06:00:00.000|Not Applicable |10027, 10031                            |
# |Manhattan|Television       |6               |United States of America|2024-06-01T22:00:00.000|2024-05-30T15:30:19.000|Mayor's Office of Media & Entertainment|788451 |Shooting Permit              |EAST   47 STREET between 1 AVENUE and 2 AVENUE,  EAST   45 STREET between 1 AVENUE and 2 AVENUE,  EAST   45 STREET between 1 AVENUE and 2 AVENUE,  EAST   46 STREET between 1 AVENUE and 2 AVENUE,  EAST   44 STREET between 1 AVENUE and 2 AVENUE,  EAST   44 STREET between 2 AVENUE and 3 AVENUE,  EAST   45 STREET between 2 AVENUE and 3 AVENUE,  1 AVENUE between EAST   46 STREET and EAST   47 STREET,  EAST   46 STREET between 2 AVENUE and 3 AVENUE,  EAST   46 STREET between 2 AVENUE and 3 AVENUE|17              |2024-06-01T06:00:00.000|Episodic series|10017                                   |
# |Manhattan|WEB              |8               |United States of America|2024-06-03T21:00:00.000|2024-05-30T14:51:33.000|Mayor's Office of Media & Entertainment|788425 |Shooting Permit              |EAST   95 STREET between 1 AVENUE and 2 AVENUE,  EAST   95 STREET between 1 AVENUE and 2 AVENUE                                                                                                                                                                                                                                                                                                                                                                                                                |19              |2024-06-02T06:00:00.000|Not Applicable |10128                                   |
# |Manhattan|Still Photography|1               |United States of America|2024-06-04T20:00:00.000|2024-05-30T14:48:21.000|Mayor's Office of Media & Entertainment|788423 |Shooting Permit              |BEAVER STREET between NEW STREET and BROAD STREET,  BEAVER STREET between NEW STREET and BROADWAY                                                                                                                                                                                                                                                                                                                                                                                                              |1               |2024-06-04T06:00:00.000|Not Applicable |10004                                   |
# |Manhattan|Film             |5, 64, 8        |United States of America|2024-06-03T20:00:00.000|2024-05-30T14:07:32.000|Mayor's Office of Media & Entertainment|788404 |Shooting Permit              |EAST   59 STREET between PARK AVENUE and LEXINGTON AVENUE,  EAST   62 STREET between 5 AVENUE and MADISON AVENUE,  MADISON AVENUE between EAST   61 STREET and EAST   62 STREET                                                                                                                                                                                                                                                                                                                                |18, 19, 22      |2024-06-03T06:00:00.000|Feature        |10022, 10065                            |
# |Manhattan|Commercial       |2               |United States of America|2024-06-04T23:00:00.000|2024-05-30T13:28:00.000|Mayor's Office of Media & Entertainment|788392 |Shooting Permit              |GREENE STREET between BROOME STREET and SPRING STREET,  GREENE STREET between BROOME STREET and GRAND STREET                                                                                                                                                                                                                                                                                                                                                                                                   |1               |2024-06-04T08:00:00.000|Commercial     |10012, 10013                            |
# |Brooklyn |WEB              |1               |United States of America|2024-06-01T22:00:00.000|2024-05-30T12:24:20.000|Mayor's Office of Media & Entertainment|788373 |Shooting Permit              |SCHOLES STREET between WATERBURY STREET and BUSHWICK AVENUE                                                                                                                                                                                                                                                                                                                                                                                                                                                    |90              |2024-06-01T07:00:00.000|Not Applicable |11206                                   |
# |Bronx    |Commercial       |4               |United States of America|2024-06-04T19:30:00.000|2024-05-30T11:14:49.000|Mayor's Office of Media & Entertainment|788342 |Shooting Permit              |EAST  161 STREET between WALTON AVENUE and GERARD AVENUE,  EAST  161 STREET between WALTON AVENUE and GRAND CONCOURSE                                                                                                                                                                                                                                                                                                                                                                                          |44              |2024-06-04T06:00:00.000|Commercial     |10451                                   |
# |Manhattan|Theater          |7               |United States of America|2024-06-11T23:59:00.000|2024-05-30T11:04:34.000|Mayor's Office of Media & Entertainment|788340 |Theater Load in and Load Outs|WEST   62 STREET between BROADWAY and COLUMBUS AVENUE,  BROADWAY between WEST   62 STREET and WEST   63 STREET                                                                                                                                                                                                                                                                                                                                                                                                 |20              |2024-06-03T00:01:00.000|Theater        |10023                                   |
# |Manhattan|Film             |1, 10, 11, 64   |United States of America|2024-06-04T03:00:00.000|2024-05-30T10:06:11.000|Mayor's Office of Media & Entertainment|788317 |Shooting Permit              |WEST  110 STREET between ADAM CLAYTON POWELL BOULEVARD and DUKE ELLINGTON CIRCLE,  EAST  108 STREET between 5 AVENUE and MADISON AVENUE                                                                                                                                                                                                                                                                                                                                                                        |22, 23, 28, 40  |2024-06-03T18:00:00.000|Feature        |10023, 10024, 10025, 10026, 10029, 10454|
# +---------+-----------------+----------------+------------------------+-----------------------+-----------------------+---------------------------------------+-------+-----------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------+-----------------------+---------------+----------------------------------------+
# only showing top 20 rows
