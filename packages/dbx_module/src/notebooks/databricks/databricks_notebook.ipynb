# %% [markdown]
# # Databricks notebook
#
# This Databricks notebook is executed using a Lakeflow job as defined in resources/sample_job.job.yml.

# %%
from databricks.connect import DatabricksSession

# spark = DatabricksSession.builder.serverless().profile("databricks-cli").getOrCreate()
spark = DatabricksSession.builder.getOrCreate()

# %%
df = spark.read.table("samples.nyctaxi.trips")
df.show(5)
# Out:
# ...
# +--------------------+---------------------+-------------+-----------+----------+-----------+
# |tpep_pickup_datetime|tpep_dropoff_datetime|trip_distance|fare_amount|pickup_zip|dropoff_zip|
# +--------------------+---------------------+-------------+-----------+----------+-----------+
# | 2016-02-13 21:47:53|  2016-02-13 21:57:15|          1.4|        8.0|     10103|      10110|
# | 2016-02-13 18:29:09|  2016-02-13 18:37:23|         1.31|        7.5|     10023|      10023|
# | 2016-02-06 19:40:58|  2016-02-06 19:52:32|          1.8|        9.5|     10001|      10018|
# | 2016-02-12 19:06:43|  2016-02-12 19:20:54|          2.3|       11.5|     10044|      10111|
# | 2016-02-23 10:27:56|  2016-02-23 10:58:33|          2.6|       18.5|     10199|      10022|
# +--------------------+---------------------+-------------+-----------+----------+-----------+
# only showing top 5 rows

# %%
# import sys
# sys.path.append("../src")

from dbx_module import taxis

#
taxis.find_all_taxis().show(10)
# Out:
# ...
# +--------------------+---------------------+-------------+-----------+----------+-----------+
# |tpep_pickup_datetime|tpep_dropoff_datetime|trip_distance|fare_amount|pickup_zip|dropoff_zip|
# +--------------------+---------------------+-------------+-----------+----------+-----------+
# | 2016-02-13 21:47:53|  2016-02-13 21:57:15|          1.4|        8.0|     10103|      10110|
# | 2016-02-13 18:29:09|  2016-02-13 18:37:23|         1.31|        7.5|     10023|      10023|
# | 2016-02-06 19:40:58|  2016-02-06 19:52:32|          1.8|        9.5|     10001|      10018|
# | 2016-02-12 19:06:43|  2016-02-12 19:20:54|          2.3|       11.5|     10044|      10111|
# | 2016-02-23 10:27:56|  2016-02-23 10:58:33|          2.6|       18.5|     10199|      10022|
# | 2016-02-13 00:41:43|  2016-02-13 00:46:52|          1.4|        6.5|     10023|      10069|
# | 2016-02-18 23:49:53|  2016-02-19 00:12:53|         10.4|       31.0|     11371|      10003|
# ...

# %%
# %sql

spark.sql("select * from samples.nyctaxi.trips limit 20")
# Out:
# ---------------------------------------------------------------------------
# ParseException                            Traceback (most recent call last)
# Cell In[4], line 2
#       1 global _sqldf
# ----> 2 _sqldf = spark.sql('''spark.sql("select * from samples.nyctaxi.trips limit 20")''')
#       3 _sqldf
#
# File ~/IdeaProjects/bd-python-module/.venv/lib/python3.12/site-packages/pyspark/sql/connect/session.py:909, in SparkSession.sql(self, sqlQuery, args, **kwargs)
#     906         _views.append(SubqueryAlias(df._plan, name))
#     908 cmd = SQL(sqlQuery, _args, _named_args, _views)
# --> 909 data, properties, ei = self.client.execute_command(cmd.command(self._client))
#     910 if "sql_command_result" in properties:
#     911     df = DataFrame(CachedRelation(properties["sql_command_result"]), self)
#
# ...
